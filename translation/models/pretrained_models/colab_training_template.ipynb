# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model_name = "????"

# %%
from torch.utils.data import Dataset

class TranslationDataset(Dataset):

    def __init__(self, file_paths, reverse=False, transform=None, target_transform=None):
        def read_from_file(file_path):
            with open(file_path, "r", encoding="UTF-8") as f:
                for i, line in enumerate(f):
                    if i % 2 == 0:
                        self.data.append([line.strip()])
                    else:
                        self.data[-1].append(line.strip())

        self.data = []
        self.back = reverse
        self.transform = transform
        self.target_transform = target_transform

        if type(file_paths) is str:
            read_from_file(file_paths)
        elif type(file_paths) in (list, tuple):
            for file_path in file_paths:
                read_from_file(file_path)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx][0]
        target = self.data[idx][1]
        if self.transform:
            sample = self.transform(sample)
        if self.target_transform:
            target = self.target_transform(target)
        if self.back:
            return target, sample
        else:
            return sample, target

# %%
import json

class GecDataset(Dataset):
    def __init__(self, file_path, transform=None, target_transform=None):
        self.data = []
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                data = json.loads(line)
                incorrect_sentence = data["incorrect"]
                correct_sentence = data["correct"]
                self.data.append((incorrect_sentence, correct_sentence))
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample, target = self.data[idx]
        if self.transform:
            sample = self.transform(sample)
        if self.target_transform:
            target = self.target_transform(target)
        return sample, target

# %%
from transformers import MT5ForConditionalGeneration, MT5Tokenizer, Trainer, TrainingArguments, DataCollatorForSeq2Seq
import torch
import os
print(torch.cuda.is_available())

# Load the tokenizer and model

tokenizer = MT5Tokenizer.from_pretrained(model_name)
model = MT5ForConditionalGeneration.from_pretrained(model_name)
for param in model.parameters():
  param.data = param.data.contiguous()

# Define a function to tokenize the inputs
def tokenize_function(sample_target_pair):
    sample, target = sample_target_pair
    model_inputs = tokenizer(sample, max_length=16, truncation=True, padding="max_length", return_tensors="pt")
    labels = tokenizer(target, max_length=16, truncation=True, padding="max_length", return_tensors="pt").input_ids
    labels[labels == tokenizer.pad_token_id] = -100
    model_inputs["labels"] = labels
    for key in model_inputs:
        model_inputs[key] = model_inputs[key].view(-1)
    return model_inputs

def tokenize(dataset):
  return  [tokenize_function(pair) for pair in dataset]


# Load your custom dataset
translation_dataset = TranslationDataset("/content/drive/MyDrive/PSL-Translator/data.txt")
train_translation, val_translation = torch.utils.data.random_split(translation_dataset, (0.95, 0.05))
train_translation = tokenize(train_translation)
val_translation = tokenize(val_translation)

gec_dataset = GecDataset("/content/drive/MyDrive/PSL-Translator/gec_dataset.jsonl")

train_gec, val_gec = torch.utils.data.random_split(gec_dataset, (0.95, 0.05))
train_gec = tokenize(train_gec)
val_gec = tokenize(val_gec)

# Define data collator
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# Set training arguments
training_args = TrainingArguments(
    output_dir=f"/content/drive/MyDrive/PSL-Translator/{model_name}",  # output directory
    evaluation_strategy="epoch",  # evaluation during each epoch
    learning_rate=3e-5,  # learning rate
    per_device_train_batch_size=8,  # batch size
    per_device_eval_batch_size=8,  # evaluation batch size
    weight_decay=0.01,  # weight decay for regularization
    save_total_limit=2,  # limit total checkpoint saves
    num_train_epochs=10,  # number of epochs to train        # enables text generation for evaluation
    logging_dir="./logs",  # directory for storing logs
    logging_steps=10,
    report_to="none",
    save_strategy="epoch"
)
# Out:
# True
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/376 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/702 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
# Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_gec,
    eval_dataset=val_gec,
    data_collator=data_collator,
)

# Train the model
trainer.train()
# Out:
# '# Trainer instance\ntrainer = Trainer(\n    model=model,\n    args=training_args,\n    train_dataset=train_gec,\n    eval_dataset=val_gec,\n    data_collator=data_collator,\n)\n\n# Train the model\ntrainer.train()'

# %%
# Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_translation,
    eval_dataset=val_translation,
    data_collator=data_collator,
)

# Train the model
trainer.train(resume_from_checkpoint = "/content/drive/MyDrive/PSL-Translator/results/checkpoint-1000")
# Out:
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight'].
# /usr/local/lib/python3.10/dist-packages/transformers/data/data_collator.py:656: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:278.)
#   batch["labels"] = torch.tensor(batch["labels"], dtype=torch.int64)
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:2833: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint_rng_state = torch.load(rng_file)
#     <div>
#
#       <progress value='10250' max='10250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10250/10250 1:02:58, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.099000</td>
#       <td>2.520235</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.472400</td>
#       <td>0.731277</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.151500</td>
#       <td>0.593459</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.810800</td>
#       <td>0.544146</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.083300</td>
#       <td>0.491236</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.474800</td>
#       <td>0.473967</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.590100</td>
#       <td>0.465713</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.704000</td>
#       <td>0.448225</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.595900</td>
#       <td>0.448925</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.501100</td>
#       <td>0.443133</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10250, training_loss=0.8123898086547852, metrics={'train_runtime': 3781.3446, 'train_samples_per_second': 21.667, 'train_steps_per_second': 2.711, 'total_flos': 3069932799098880.0, 'train_loss': 0.8123898086547852, 'epoch': 10.0})

# %%
model.eval()
with torch.no_grad():
  for data in val_translation:
    outputs = model.generate(data['input_ids'].unsqueeze(0).to("cuda"))
    print(tokenizer.decode(data['input_ids'], skip_special_tokens=True))
    print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Ja zimowe ubranie założyć
# Założyłem zimowe ubranie
# Oni grać piłka nożna
# Oni grają w piłkę nożną
# Czy ty kot lubić mieć?
# Czy lubisz mieć kota?
# Ja zupa pomidorowa gotować
# Gotuję zupę pomidorową
# Ona na obiad gotować.
# Ona gotuje obiad.
# Ona stół nakrywać na obiad
# Ona nakryła stół na obiad
# Ona pies kochać bardzo
# Ona bardzo kocha psa
# Ty wczoraj kino iść
# Czy poszłem wczoraj do kina?
# My wieczór przyjaciel odwiedzać często
# Często odwiedzamy przyjaciela wieczorem
# Ja wieczorem książka czytać
# Czytam książkę wieczorem
# My wycieczka planować wspólnie
# Planujemy wspólnie wycieczkę
# On historia pisać
# On pisze historię
# On samochód czerwony mieć
# On ma czerwony samochód
# Ja kiedy ostatnio urlop mieć?
# Kiedy ostatnio mam urlop?
# Ona rower jechać
# Ona jeździ rowerem
# My przyjaciel spotkanie co weekend
# Co weekend spotykamy się z przyjacielem
# Dlaczego ty płakać?
# Dlaczego płakasz?
# Ty muzyka słuchać teraz?
# Czy teraz słuchasz muzyki?
# Ty urodziny blisko mieć?
# Masz blisko urodziny?
# Ja napój zimny pić
# Piję zimny napój
# Oni razem książki pisać
# Oni piszą razem książki
# Wy gdzie wczoraj być
# Gdzie byliście wczoraj?
# On muzyka koncert grać.
# On gra na koncercie muzyki.
# My wakacje wybrać ciepło
# Wybieramy ciepłe wakacje
# Ty rower mieć?
# Masz rower?
# Oni książka czytać cała noc
# Oni czytają książkę całą noc
# Czy wy film oglądać wczoraj
# Czy oglądałeś film wczoraj?
# Ty film komedia obejrzeć chęć?
# Czy chcesz obejrzeć film?
# Wy woda pić często?
# Czy często picie wodę?
# Ona telewizja mało oglądać
# Ona mało ogląda telewizję
# Ja pracować firma duża teraz
# Pracuję teraz w dużym biurze
# Ty muzyka słuchać teraz?
# Czy teraz słuchasz muzyki?
# My wiosna kwiaty ogród sadzić
# Sadzimy kwiaty w ogrodzie na wiosnę
# Ja ciepłe ubranie założyć
# Założyłem ciepłe ubranie
# Ty rower naprawić sam?
# Naprawiłeś rower sam?
# Ja ty wczoraj spotkać
# Spotkałem się wczoraj
# Ona pływać w basenie lubić
# Ona lubi pływać w basenie
# Ja pies spacerować codziennie
# Codziennie spaceruję z psem
# Ona fotografia nowa robić
# Ona robi nową fotografię
# Ona mieszać kawa z mleko
# Ona miesza kawę z mlekiem
# Ona pomóc potrzebować teraz
# Ona potrzebuje teraz pomóc
# Ona pisze książka teraz
# Ona teraz pisze książkę
# My rodzinny weekend planować
# Planujemy rodzinny weekend
# My zakupy robić wczoraj
# Robiliśmy zakupy wczoraj
# My dzisiaj deszcz spacer
# Spacerujemy dzisiaj na deszcz
# Ty podróżować gdzie najbardziej lubić
# Gdzie najbardziej lubisz podróżować?
# Ty pies wyprowadzać na spacer
# Wyprowadzasz psa na spacer
# Ja rośliny podlewać
# Podlewam rośliny
# On nowy kolega w pracy polubić szybko
# On szybko polubił nowego kolegę w pracy
# My koncert pójść chcieć.
# Chcemy pójść na koncert
# My razem film oglądać będzie
# Oglądamy razem film
# Ja język migowy uczyć się chcę
# Chcę się uczyć języka migowego
# Kiedy weekend film ogląda my?
# Kiedy oglądamy film w weekend?
# Ty jutro Warszawa odwiedzać
# Jutro odwiedzisz Warszawę
# Oni zamawiać kolacja restauracja
# Oni zamawiają kolację w restauracji
# My ostatnio park odwiedzać
# Odwiedziły ostatnio park
# Ona dzwonić do ciebie wczoraj chcieć
# Chciała wczoraj dzwonić do ciebie
# My sport uprawiać
# Uprawiamy sport
# Dziecko rano wstawać
# Dziecko rano wstaje
# Ty nauczyciel być dobrze?
# Czy jesteś dobrze nauczycielem?
# Ty książka sprzedać?
# Czy sprzedałeś książkę?
# On wieczór telewizja oglądać
# On ogląda telewizję wieczorem
# Ona książka biblioteka oddać wczoraj
# Ona oddała książkę do biblioteki wczoraj
# My razem kupić prezent
# Kupujemy razem prezent
# Ty kwiaty kupić mamie?
# Kupiłeś kwiaty mamie?
# On piosenka śpiewać pięknie
# On pięknie śpiewa piosenki
# Ja herbatę parzyć
# Parzę herbatę
# My park bieg codziennie
# Codziennie biegamy w parku
# On lekcja dom odrabiać
# On odrabia lekcje w domu
# Ja tata telefon dzwonić
# Dzwonię do taty
# On ma nową nauczycielkę
# On ma nową nauczycielkę
# Oni rower jeździć często.
# Oni często jeździją na rowerze
# My obiad gotować wspólnie
# Gotujemy obiad wspólnie
# Ty książka wybrać z półki?
# Czy wybrałeś książkę z półki?
# Ty samochód naprawiać kiedy?
# Kiedy naprawiasz samochód?
# Ja nowy język uczyć się teraz
# Uczę się teraz nowego języka
# Twoja mama urodziny prezent kupić
# Twoja mama kupiła prezent na urodziny
# My szkoła przyjaciel spotkać.
# Spotkaliśmy przyjaciela w szkole.
# Ty kuchnia gotować lubić?
# Lubisz gotować w kuchni?
# Ty znać język hiszpański?
# Czy znasz język hiszpański?
# Ona pociąg przyjechać późno.
# Ona przyjeżdża późno na pociąg
# Ja brat dzisiaj spotkać
# Spotkałem dzisiaj brata
# My szkoła kończyć
# Kończymy szkołę
# My zdjęcia robić na plaża
# Robimy zdjęcia na plaży
# Ty miasto odwiedzać często
# Czy często odwiedzasz miasto?
# Ja weekend książka czytać
# Czytam książkę w weekend
# Gdzie ona pracować teraz?
# Gdzie ona teraz pracuje?
# My projekt kończyć
# Kończymy projekt
# My w góry co roku jeździć
# Co roku jeździmy w góry
# Twój brat dom duży?
# Twój brat ma duży dom?
# Ja książka pisać
# Piszę książkę
# Ty weekend co robić plany?
# Co robisz w weekend?
# On kucharz praca lubić
# On lubi pracować jako kucharz
# On mieszkanie wynajmować obecnie
# On obecnie wynajmuje mieszkanie
# My film razem oglądać
# Oglądamy razem film
# Ja poniedziałek ćwiczenia zaczynać
# Zaczynam ćwiczenia w poniedziałek
# Ja sport lubić bardzo
# Bardzo lubię sport
# Ona książka biblioteka brać
# Ona brała książkę w bibliotece
# Ona dyskoteka tańczyć dużo
# Ona dużo tańczyła na dyskopie
# On imię jak?
# Jakie jest jego imię?
# Ty chcieć pić sok
# Chcesz pić sok?
# Ja niebo gwiazdy noc oglądać lubię.
# Lubię oglądać gwiazdy w niedzielę.
# On nigdy nie zapominać klucz
# On nigdy nie zapomina klucza
# Ja nie zdążyć na pociąg
# Nie zdążyłem na pociąg
# Ty zdecydować gdzie na wakacje jechać?
# Gdzie zdecydowałeś jechać na wakacje?
# On często grać piłka nożna
# On często gra w piłkę nożną
# Ty samochód nowy mieć?
# Masz nowy samochód?
# Ty wakacje Hiszpania spędzać?
# Spędzasz wakacje w Hiszpanii?
# Ona wczoraj nowa bluzka kupić
# Ona kupiła nową bluzkę wczoraj
# Ty muzyka słuchać lubić
# Lubisz słuchać muzyki
# On film komedia oglądać
# On ogląda komedię
# Ty sport uprawiać który
# Który sport uprawiasz
# Ja rowerowy wyścig przyjaciel
# Przyjaciel mnie wyściguje rowerem
# On książka pożyczyć od kolega
# On pożyczył książkę od kolegi
# Ty komputer nowy kupić już?
# Czy kupiłeś już nowy komputer?
# Ty koń jeździć umieć?
# Umiesz jeździć na koń?
# Ja gry komputerowe grać
# Grałem w gry komputerowe
# My wyjazd planować
# Planujemy wyjazd
# Ja przyjaciel odwiedzać
# Odwiedziłem przyjaciela
# Ty preferować chleb biały czy ciemny
# Preferujesz biały chleb czy ciemny
# My park spacer.
# Spacerujemy po parku.
# On piosenka słucha aktualnie.
# On aktualnie słucha piosenek.
# On biegać codziennie rano
# On codziennie rano biega
# Dziadek na rower jeździć codziennie
# Dziadek codziennie jeździ na rowerze
# On film oglądać wieczór
# On ogląda film wieczorem
# Ona telefon zgubić wczoraj
# Ona zgubiła telefon wczoraj
# Ja nowy rower kupować ostatnio
# Kupiłem ostatnio nowy rower
# Ty wczoraj do pracy późno wrócić.
# Czy wróciłeś wczoraj późno do pracy?
# On książka napisać sam.
# On sam napisał książkę.
# On nauka chemia teraz trudne mieć
# On ma trudne teraz naukę chemii
# Ty zimowy lubić sport?
# Lubisz sport zimowy?
# My razem mieszkać Warszawa
# Spacerujemy razem w Warszawie
# Słońce rankiem wschodzić ładnie
# Słońce ładnie wschodzi na rankiem
# My dom kupić razem
# Kupujemy dom razem
# Biblioteka książki dużo mieć
# Biblioteka ma dużo książek
# On las chodzić często
# On często chodzi do lasu
# Ty lato rower jazda gdzie?
# Gdzie jeździsz rowerem latem?
# Oni nauka język obcy rozpoczynać
# Oni rozpoczynają naukę języka obcego
# Ty samochód nowy kupić kiedy?
# Kiedy kupiłeś nowy samochód?
# Ona piękna sukienka nosić.
# Ona nosi piękną sukienkę.
# Ona kurs hiszpański podjąć
# Ona podjęła kurs hiszpański
# My sobota sprzątać, potem do znajomi wyj
# Sprzątamy znajomych w sobotę
# Książka naprawdę interesować mnie
# Książka naprawdę interesuje mnie
# Co robisz w weekend?
# Co robisz w weekend?
# Przyjaciel bliźniak mieć ja
# Przyjaciel ma bliźniaka
# On codziennie kawa pić
# On codziennie pije kawę
# Ona siostra mała szkoła chodzi.
# Ona chodzi do szkoły z siostrą.
# Ty wiedzieć sprawa ważna?
# Czy wiesz, że ważna sprawa?
# Ty kuchnia kolacja przygotowywać
# Przygotowujesz kolację w kuchni
# Ona taniec lubić bardzo
# Ona bardzo lubi taniec
# Ty spacerować park?
# Spacerujesz po parku?
# Ty przyjaciele mieć ilu
# Ile masz przyjaciół?
# Dziecko malować dom farba
# Dziecko maluje dom farbą
# On film science fiction oglądać.
# On ogląda film science fiction.
# Ja pływać w morze lato
# Pływam w morzu latem
# Ty woda picie dzisiaj dużo
# Czy dzisiaj dużo pijesz wody?
# My razem obiad jeść
# Jemy razem obiad
# My sprzątać dom jutro razem
# Jutro razem sprzątamy dom
# On szczęśliwy wakacje być
# On jest szczęśliwy na wakacjach
# Ja piec ciasto piec
# Piekę ciasto
# Samolot startować już
# Samolot już startuje
# My las biegać codziennie.
# Codziennie biegamy w lesie.
# Ja dom budować planuje
# Planuję budować dom
# Ja tenis grać raz w tydzień
# Gram raz w tenisie w tygodniu
# My koncert muzyka słuchać
# Słuchamy muzyki na koncercie
# Ty praca zmiana kiedy
# Kiedy zmiana pracy?
# Ja lody czekoladowe jeść
# Jem czekoladę
# My drzewo przycinać w ogród
# Przypinamy drzewo w ogrodzie
# Ty mieszkać gdzie?
# Gdzie mieszkasz?
# Ty telewizja oglądać?
# Oglądasz telewizję?
# Ja dom budować
# Buduję dom
# Ty kawa pić codziennie chęć?
# Chcesz codziennie pić kawę?
# Ty jeść kolacja co najczęściej?
# Co najczęściej jesz kolację?
# Ja książka ulubiona czytać
# Czytam moją ulubioną książkę
# My park spacerować
# Spacerujemy po parku
# Ja czas na relaks mieć.
# Mam czas na relaks
# On sport codziennie trenować
# On codziennie trenuje sport
# Ona biegać w parku
# Ona biega w parku
# Ty kichanie być alergia
# Czy jest alergia na kichanie?
# Ty który film oglądać?
# Który film oglądasz?
# My kwiaty podlewać w domu
# Podlewamy kwiaty w domu
# Ja wczoraj las spacerować
# Spacerowałem wczoraj po lesie
# Ty urlop planować na wakacje
# Planujesz urlop na wakacje?
# Ja śpiewać karaoke dziś
# Dziś śpiewam karaoke
# Ja film zobaczyć.
# Wczoraj zobaczyłem film.
# Ty dom skończyć budowa?
# Skończyłeś budowę domu?
# Jak on nazywać się?
# Jak on nazywa się?
# Ja wiosna spacer park uwielbiać
# Uwielbiam spacery po parku wiosną
# Ty kawa herbata pić co?
# Co pijesz kawę i herbatę?
# Ona zakupy robić w sklep osiedlowy
# Ona robi zakupy w sklepie osiedlowym
# Ona górska wędrówka lubić
# Ona lubi wędrówki w górach
# Dziecko szkoła wracać po obiad
# Dziecko wraca po obiad do szkoły
# My plac zabaw zbudować
# Zbudowaliśmy plac zabaw
# Ona piosenka śpiewać pięknie
# Ona pięknie śpiewa piosenki
# Ty woda mineralna pić codziennie?
# Czy pijesz wodę mineralną codziennie?
# Ja kawa czarny pić zazwyczaj
# Zazwyczaj piję czarną kawę
# Ty szkoła wczoraj iść było
# Czy idziesz wczoraj do szkoły?
# Ja obiad gotować teraz
# Teraz gotuję obiad
# Ty wyjazd planować
# Planujesz wyjazd
# Ty woda butelka chcieć?
# Chcesz wodę do butelki?
# On biegać park codziennie
# On codziennie biega w parku
# Ty woda pić?
# Pijesz wodę?
# Ty sklep wczoraj pójść
# Czy poszłeś wczoraj do sklepu?
# Ja warzywa jeść zdrowie
# Jem warzywa z zdrowiem
# My książka pisać wspólnie
# Pisiemy książkę wspólnie
# My razem jeść obiad
# Jemy razem obiad
# Ja lubić muzyka słuchać
# Lubię słuchać muzyki
# Ty kino film zobaczyć już?
# Czy widziałeś film w kinie?
# Ona uczyć się nowy język teraz
# Ona teraz uczy się nowego języka
# Ty na wakacje gdzie pojechać?
# Gdzie pojechałeś na wakacje?
# Ona samochód nowy kupić
# Ona kupiła nowy samochód
# Ona kino na randka być
# Ona jest na randce w kinie
# Ty wiedzieć co?
# Czy wiesz co?
# My wakacje Grecja być
# Byliśmy na wakacjach w Grecji
# Ja deszczowa pogoda lubić
# Lubię deszczową pogodę
# Łazienka prysznic brać ty
# Łazienka brała prysznic
# Ty wiedzieć kiedy przyjść?
# Kiedy przyjdziesz?
# Ty sport uprawiać jakie?
# Jaki sport uprawiasz?
# Ja często ćwiczyć na siłownia
# Często ćwiczyłem na siłowni
# Ty słońce wschód widzieć?
# Czy widziałeś słońce na wschód?
# Ona samochód nowy kupił wczoraj
# Ona kupił nowy samochód wczoraj
# My góry wspinać się
# Wspinamy się w góry
# Oni projekt skończyć już.
# Oni już skończyli projekt.
# Ty na spacer iść wczoraj
# Czy idziesz wczoraj na spacer?
# On buty wygodne szukać w sklepie
# On szuka wygodnych butów w sklepie
# Ja lekcje odrabiać.
# Odrabiam lekcje.
# Ja komputer klawiatura wymieniać
# Wymieniłem klawiatura na komputerze
# Ty teraz kawa pić
# Czy pijesz teraz kawę?
# Ona herbata mocna pić
# Ona pije mocną herbatę
# On cichy spokojny człowiek być
# On jest spokojny człowiek
# Ja dzisiaj kawiarnia zrobić
# Zrobiłem dzisiaj kawiarnię
# Mój brat samochód prowadzić
# Mój brat prowadzi samochód
# My wakacje ciepły kraj wybrać
# Wybieramy ciepły kraj na wakacje
# My zwierzęta kochać
# Kochamy zwierzęta
# Ja chory czuję się
# Czuję się chory
# Ja brat szkoła razem chodzić
# Chodzę razem do szkoły
# My szybko biegać
# Biegamy szybko
# Ja muzyka klasyczna słuchać relaks
# Słucham muzyki klasycznej na relaksie
# Ty mecz piłka nożna oglądać wieczór?
# Oglądasz mecz piłki nożnej wieczorem?
# My pies przyjaciel na spacer iść
# Idziemy z psem na spacer z przyjacielem
# Dziecko lody smakować bardzo
# Dziecko bardzo smakuje lodów
# My zegarek naprawić w warsztat
# Naprawiamy zegarek w warsztatie
# My kuchnia nowe danie próbować
# Próbujemy nowe danie w kuchni
# Ja w domu odpoczywać teraz
# Teraz odpoczywam w domu
# Ona dzisiaj nie dom.
# Ona dzisiaj nie chodzi do domu.
# My woda pić dużo codziennie
# Codziennie pijemy dużo wody
# Ty komputer grać w gry?
# Czy grasz na komputerze?
# Ty książka nowa czytać
# Czytasz nową książkę
# Ty przyjaciel mieć?
# Masz przyjaciela?
# Ja jabłko jeść
# Jem jabłko
# Ty pogoda dzisiaj wiedzieć jaka
# Jaka jest dzisiaj pogoda?
# Ty umiesz gotować?
# Umiesz gotować?
# Ty kiedy książka czytać?
# Kiedy czytasz książkę?
# Ja gazetę rano kupić
# Kupiłem gazetę rano
# Oni książka kupować
# Oni kupują książkę
# On samochód nowy kupić wczoraj
# On kupił wczoraj nowy samochód
# Ona herbata z cytryna pić
# Ona pije herbatę z cytryną
# Ty szybko biegać
# Czy szybko biegasz?
# My razem gotować obiad dzisiaj
# Dzisiaj gotujemy razem obiad
# Ty dzisiaj jak czuć?
# Jak dzisiaj czujesz?
# Ty restauracja jeść co?
# Co jesz w restauracji?
# Ja pies spacer z
# Spaceruję z psem z psem
# Ty praca zaczynać kiedy?
# Kiedy zaczynasz pracę?
# Ona autobus na przystanku czekać
# Ona czeka na autobus na przystanku
# On telewizja ogląda wczoraj
# On oglądał telewizję wczoraj
# Ty pudełko czekolada podarować?
# Czy podarujesz pudełko czekolady?
# My podróżować samochód długi dystans
# Podróżujemy długi dystans samochodem
# On park spacerować
# On spaceruje po parku
# On przyjaciółka spotkać park
# On spotyka przyjaciółkę w parku
# Czy on dzisiaj pracy być?
# Czy on jest dzisiaj w pracy?
# Ja siostra odwiedzić jutro
# Jutro odwiedzę siostrę
# On kolacja dla rodzina gotować
# On gotuje kolację dla rodziny
# Ja woda pić
# Piję wodę
# Ona nowy film obejrzeć w kinie
# Ona obejrzała nowy film w kinie
# My szkoła chodzić co dzień
# Chodzimy do szkoły codziennie
# My czwartek spotkać
# Spotkamy się w czwartek
# Wydarzenie na pewno miejsce mieć
# Wydarzenie na pewno ma miejsce
# Ona pies weterynarz zabierać
# Ona zabiera psa do weterynarza
# Ty herbata pić nie chcieć
# Nie chcesz pić herbaty
# On latem urlop mieć
# On ma urlop latem
# On samochód myć w garażu
# On myje samochód w garażu
# Ona przyjaciel odwiedzać
# Ona odwiedza przyjaciela
# Ty pies posiadać
# Czy masz psa?
# Ona woda pić
# Ona pije wodę
# Ty kawę z mlekiem pić?
# Pijesz kawę z mlekiem?
# On na gitarze grać.
# On gra na gitarze.
# Ja książka ukończyć w marzec.
# Ukończyłem książkę w marzec.
# Ty teraz co robić?
# Co teraz robisz?
# Pies na spacer z dziecko
# Pies spaceruje z dzieckiem
# Ty dom sprzedawać chcieć
# Chcesz sprzedać dom?
# Ty gdzie mieszkać?
# Gdzie mieszkasz?
# Kiedy my wyjście na zakupy planować?
# Kiedy planujemy wyjście na zakupy?
# Ona wakacje wybrać miejsce
# Ona wybrała miejsce na wakacje
# Ja komputer grać wczoraj wieczór
# Gram wczoraj wieczorem na komputerze
# Oni wesele tańczyć całą noc
# Oni tańczą całą noc w wesele
# Ty książka ulubiona co to?
# Co to jest twoja ulubiona książka?
# My szkoła razem chodzić
# Chodzimy razem do szkoły
# Ja komputer naprawić próbować.
# Próbuję naprawić komputer.
# Ja obiad już zjeść
# Już zjadłem obiad
# Oni nowa kawiarnia otworzyć.
# Oni otworzyć nową kawiarnię.
# On na rower jeździć codziennie
# On codziennie jeździ na rowerze
# My pracować na projekt wspólnie
# Pracujemy wspólnie na projektze
# Ja wtorek wolny mieć
# Mam wolny wtorek
# Ja jutro rano fitness siłownia
# Jutro rano rano będę na siłowni
# Ona pies lubić
# Ona lubi psa
# My miasto zwiedzać lubić
# Lubimy zwiedzać miasto
# On wieczór książka czytać.
# On czyta książkę wieczorem.
# Ona zakupy robić sama
# Ona sama robi zakupy
# Ona samochód prowadzić
# Ona prowadzi samochód
# Ty siostra mieć?
# Masz siostrę?
# Kiedy koncert kończyć?
# Kiedy kończysz koncert?
# Ona list pisać
# Ona pisze list
# Ja pies spacer codziennie
# Codziennie spaceruję z psem
# Ja muzyka nowa odkrywać
# Odkrywam nową muzykę
# Ja na rowerze jeździć zabawa
# Jeżdżę na rowerze za zabawą
# Lubić ty kawa
# Lubisz kawę
# My nowy film oglądać
# Oglądamy nowy film
# Ja lubić jabłko bardzo
# Bardzo lubię jabłko
# On telefon dzwonić
# On dzwoni telefonem
# On piłka grać
# On gra w piłkę
# Drzewo zielone być
# Drzewo jest zielone
# Kot okno wyglądać
# Kot wyglądał na okno
# Ja gazetę codziennie czytać rano
# Codziennie czytam gazetę rano
# Ty grać piłka gdzie?
# Gdzie grasz w piłkę?
# Ja obiad wczoraj zjeść było
# Zjadłem obiad wczoraj
# My pokój dziecko sprzątać
# Sprzątamy pokój dziecka
# Ty klucz samochód zgubić?
# Zgubiłeś klucz do samochodu?
# Ty jeść śniadanie co?
# Co jesz na śniadanie?
# On film dobry oglądać wczoraj
# On oglądał dobry film wczoraj
# Ja komputer używać teraz
# Używam teraz komputera
# Ja woda mineralna pić
# Piję wodę mineralną
# Kwiaty ładnie rosnąć w ogród
# Kwiaty ładnie rosną w ogrodzie
# On papuga mówić nauczyć już
# On już nauczył się mówić papugi
# My wycieczka góry planować
# Planujemy wycieczkę w góry
# Ty szkoła kiedy?
# Kiedy masz szkołę?
# My lato urlop planować
# Planujemy urlop latem
# Książka na stole leżeć.
# Książka leży na stole.
# Ja nowy komputer kupić
# Kupiłem nowy komputer
# My parkować tam
# Parkujemy tam
# Ona nigdy nie biuro pracować
# Ona nigdy nie pracuje w biurze
# Ona wieczorem czytać lubić
# Ona lubi czytać wieczorem
# On koty dwa posiadać
# On ma dwa koty
# On sklep kupić jedzenie
# On kupił jedzenie w sklepie
# On nowy telefon kupić tydzień temu
# On kupił nowy telefon tydzień temu
# Ja książka czytać lubi
# Lubię czytać książki
# My park biegać
# Biegamy w parku
# On książki przeczytać całkowicie
# On całkowicie przeczytał książkę
# Ty nauczyciel pomoc potrzebować
# Czy potrzebujesz pomocy nauczyciela?
# Drzewo zielone czemu
# Czemu jest zielone drzewo?
# Ja zupa gotować teraz
# Teraz gotuję zupę
# On zadowolony wygląda
# On wygląda zadowolony
# On bardzo dobrze gotować
# On bardzo dobrze gotuje
# On kwiaty podarować dziewczyna
# On podarował kwiaty do dziewczyny
# Ona pływać wakacje
# Ona pływa na wakacjach
# Ja wieczorem spacer robić lubię
# Lubię robić spacer wieczorem
# Ona książka bardzo lubić
# Ona bardzo lubi czytać książki
# Słucham muzyki na słuchawkach
# Słucham muzyki na słuchawkach
# Ja sport uprawiać codziennie
# Codziennie uprawiam sport
# Ja nie mieć czas teraz
# Nie mam teraz czasu
# Ja woda pić dużo
# Piję dużo wody
# Ja wakacje spędzać góry planować
# Planuję spędzać wakacje w górach
# My razem spacer park
# Spacerujemy razem po parku
# Ona książka czytać
# Ona czyta książkę
# My z przyjaciółmi grać planszowe wieczorem
# Gramy z przyjaciółmi wieczorem
# Ty kto wczoraj dzwonić?
# Kto dzwoni wczoraj?
# Ty sport uprawiać regularnie?
# Czy regularnie uprawiasz sport?
# Ty praca skończyć kiedy?
# Kiedy skończysz pracę?
# Ty mieszkanie wynająć gdzie?
# Gdzie wynajrzysz mieszkanie?
# Ja codziennie lekcje robić
# Codziennie robię lekcje
# On komputer naprawić fachowo
# On fachowo naprawił komputer
# Ty pływać nauczyć się
# Nauczysz się pływać
# Ja świat marzyć
# Marzę o świecie
# On muzyka słuchać teraz
# On teraz słucha muzyki
# On nowa koszula na spotkanie kupić
# On kupił nową koszulę na spotkanie
# My w przyszłym tygodniu wyjazd rodzinny planować
# Planujemy wyjazd rodzinny w przyszłym tygodniu
# Kino film najnowszy oglądać
# Oglądasz najnowszy film w kinie
# Ona nowe buty mieć
# Ona ma nowe buty
# Ja zegarek nosić
# Nosiłem zegarek
# Ty telewizja oglądać teraz?
# Oglądasz teraz telewizję?
# Ona rower kupić w zeszłym tygodniu
# Ona kupiła rower w zeszłym tygodniu
# Ja ty rozumieć
# Rozumiem się
# Ty dzisiaj obiad gotować?
# Czy gotujesz dzisiaj obiad?
# Oni na wakacje Grecja lecieć
# Oni lecą na wakacje w Grecji
# My film oglądać wieczór
# Oglądamy film wieczorem
# Ja wyjazd planować na przyszły miesiąc
# Planuję wyjazd na przyszły miesiąc
# Ja ty znać
# Znam mnie
# My planować wycieczka w góry
# Planujemy wycieczkę w góry
# Ja pies kot mieć
# Mam psa i kota
# On jabłko zjeść już
# On już zjadł jabłko
# Pies szczeka nocą
# Pies szczeka nocą
# On rynek kupować owoc
# On kupuje owoce w rynku
# My kino wieczór iść
# Idziemy do kina wieczorem
# Ona zawsze dom szybko sprzątać
# Ona zawsze szybko sprząta dom
# Ona supermarket robić zakupy teraz
# Ona teraz robi zakupy w supermarketie
# Ja urodziny obchodzić jutro.
# Jutro obchodzę urodziny.
# On dom sprzątać teraz
# On teraz sprząta dom
# My wiosna ogród uporządkować.
# Uporządkujemy ogród na wiosnę.
# Ty szczęśliwy być dziś?
# Czy jesteś dziś szczęśliwy?
# My dużo jedzenie gotować
# Gotujemy dużo jedzenia
# My jutro góry jechać planować
# Planujemy jutro jeździć w góry
# Oni park jesień spacerować
# Oni spacerują po parku jesienią
# Ja wiosna kwiaty sadzić
# Sadzię kwiaty na wiosnę
# Ona muzyka śpiewać
# Ona śpiewa muzykę
# Lubisz mocna kawa?
# Lubisz mocną kawę?
# Ty praca domowa zawsze robić
# Zawsze robisz pracę domową
# On brat być
# On jest bratem
# On telewizja nowa kupić.
# On kupił nową telewizję.
# My ciasto piec sobota
# Piekę ciasto w sobotę
# Ty rower naprawiony mieć?
# Masz naprawiony rower?
# On muzeum odwiedzać raz
# On raz odwiedza muzeum
# Ja pies czesać codziennie
# Codziennie czesałem psa
# Ona wczoraj wizyta u lekarza
# Ona wczoraj była u lekarza
# Wy wczoraj gdzie być
# Gdzie byliście wczoraj?
# Szybko jechać rower
# Szybko jedziesz na rowerze
# Ona śpiew piosenka lubić
# Ona lubi śpiewać piosenki
# Ty praca kończyć godzinę
# Czy kończysz pracę w godzinie?
# Twój brat gdzie pracować?
# Gdzie pracujesz twój brat?
# Ja autobus spóźnić się.
# Spóźniłem się na autobus.
# Ty rower rano jeździć
# Czy jeździsz rano na rowerze?
# Ona praca znajdować
# Ona znajduje pracę
# My często pizzę zamawiać
# Często zamawiamy pizzę
# Ja poniedziałek kino iść było
# Idę do kina w poniedziałek
# My szkoła projekt kończyć
# Kończymy projekt w szkole
# On książka science fiction czytać
# On czyta książkę science fiction
# On bilet kupić
# On kupił bilet
# Ona muzyka jazz słuchać cały czas
# Ona cały czas słucha jazzu
# Ja zdjęcie robić w parku
# Robię zdjęcia w parku
# Ty dziś w pracy?
# Czy dziś jesteś w pracy?
# Ty rower mieć czerwony
# Masz czerwony rower
# My obiad gotować razem
# Gotujemy razem obiad
# Mnie zimno
# Mnie zimno

# %%
torch.save(model.state_dict(), "/content/drive/MyDrive/PSL-Translator/model2.pth")

# %%
tokenizer("ja woda pić", return_tensors="pt")
# Out:
# {'input_ids': tensor([[   432,    259, 181609,    421,   7155,      1]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}
